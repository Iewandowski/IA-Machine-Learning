# %%
a = 0
a
# Out:
# 0

# %%
nome = input('Digite o nome')
print('Nome = ', nome)

idade = int(input('Digite a idade'))
print('Idade = ', idade)
# Out:
# Digite o nomea
# Nome =  a
# Digite a idade3
# Idade =  3

# %%
word = 'casaco'
print(a)

maiuscula = word.upper()
print(maiuscula)

minuscula = maiuscula.lower()
print(minuscula)

capital = word.capitalize()
print(capital)
# Out:
# 0
# CASACO
# casaco
# Casaco

# %%
metade_palavra = word[0:3] # não pega o índice 3
print(metade_palavra)

ultimas_letras = word[3:]
print(ultimas_letras)

word2 = word.replace('aco', 'inha')
print(word)
print(word2)
# Out:
# cas
# aco
# casaco
# casinha
# 2

# %%
word2.find('s') # retorna a posicao da letra
# Out:
# -1

# %%
word2.find('a')
# Out:
# 1

# %%
word2.find('b')
# Out:
# -1

# %%
word3 = ' casaco '
print(word3, ' - ',len(word3)) # conta espaços em branco

word4 = word3.strip()
print(word4, ' - ', len(word4))
# Out:
#  casaco   -  8
# casaco  -  6

# %%
n1 = 14
n2 = 16

print(f'Dividindo {n1} por {n2} o resultado é {n1/n2}')
# Out:
# Dividindo 14 por 16 o resultado é 0.875
