# %% [markdown]
# #Tratamento de erros e exceções:
#
#
# *   NameError: variável não foi definida
# *   TypeError: tipos de dados incompativeis
# *   RuntimeError: erro de execução
# *   SyntaxError: sintaxe digitada é inválida e não reconhecida pelo interpretador
# *   ZeroDivisionError: divisão por zero
# *   IndexError: índice está fora da coleção

# %% [markdown]
# ##Tipos de erros

# %%
3 = 4
# 3 == 4
# Out:
#   File "<ipython-input-2-effb9ca1a7d0>", line 1
#     3 = 4
#          ^
# SyntaxError: can't assign to literal

# %%
print('Meu nome é', nome)
# falta declarar variável nome
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9b9522567aad> in <module>()
# ----> 1 print('Meu nome é', nome)
#       2 # falta declarar variável nome
#
# NameError: name 'nome' is not defined

# %%
print(3 / 0)
# divisão por 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-5-9a01622460da> in <module>()
# ----> 1 print(3 / 0)
#       2 # divisão por 0
#
# ZeroDivisionError: division by zero

# %%
2.3 / 'cachorro'
# dados incompativeis
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-48ef6fd474fe> in <module>()
# ----> 1 2.3 / 'cachorro'
#
# TypeError: unsupported operand type(s) for /: 'float' and 'str'

# %%
c = [1,2,3,4,5]
c[5]
# erro de index
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-cf69cbe0b208> in <module>()
#       1 c = [1,2,3,4,5]
# ----> 2 c[5]
#       3 # erro de index
#
# IndexError: list index out of range

# %% [markdown]
# ##Tratamento de Erros

# %%
try:
  n = int(input('Digite um número inteiro: '))
except:
  print('Valor inválido')
else:
  print(f'Valor digitado é: {n}')
# Out:
# Digite um número inteiro: 3,3
# Valor inválido

# %%
while True:
  try:
    n = int(input('Digite um número inteiro: '))
  except:
    print('Valor inválido')
  else:
    print(f'Valor digitado é: {n}')
    break
# Out:
# Digite um número inteiro: 3,3
# Valor inválido
# Digite um número inteiro: 3,2
# Valor inválido
# Digite um número inteiro: 3
# Valor digitado é: 3

# %%
while True:
  try:
    p = int(input('Digite um número inteiro '))
  except ValueError:
      print('Valor inválido')
  except KeyboardInterrupt:
    print('Usuario interrompeu a execução ')
  else:
    print(f'Valor digitado é: {p}')
    break
# Out:
# Digite um número inteiro u
# Valor inválido
# Usuario interrompeu a execução
# Usuario interrompeu a execução
# Digite um número inteiro 4
# Valor digitado é: 4
# Digite um número inteiro 6
# Digite um número inteiro 5
